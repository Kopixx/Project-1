# %%
#import all python modules for activities
import os
import statistics as st
import csv
import math
import sys
import hvplot.pandas
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats 
import json
import requests
import numpy as np

# %%
#read the Melbourne City Real Estate data set
melb_data = pd.read_csv('Cleaned_Data.csv')
melb_data.dropna(inplace=True)

# Display sample data
melb_data.head()
# Out:
#    Unnamed: 0      Suburb          Address  Rooms Type    Price Method  \
# 1           2  Abbotsford  25 Bloomburg St      2    h  1035000      S
# 2           4  Abbotsford     5 Charles St      3    h  1465000     SP
# 4           6  Abbotsford      55a Park St      4    h  1600000     VB
# 6          11  Abbotsford     124 Yarra St      3    h  1876000      S
# 7          14  Abbotsford    98 Charles St      2    h  1636000      S
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
# 6  Nelson  7/05/2016       2.5  ...       2.0  0.0     245.0         210.0
# 7  Nelson  8/10/2016       2.5  ...       1.0  2.0     256.0         107.0
#
#    YearBuilt  CouncilArea  Lattitude Longtitude             Regionname  \
# 1     1900.0        Yarra   -37.8079   144.9934  Northern Metropolitan
# 2     1900.0        Yarra   -37.8093   144.9944  Northern Metropolitan
# 4     2014.0        Yarra   -37.8072   144.9941  Northern Metropolitan
# 6     1910.0        Yarra   -37.8024   144.9993  Northern Metropolitan
# 7     1890.0        Yarra   -37.8060   144.9954  Northern Metropolitan
#
#    Propertycount
# 1         4019.0
# 2         4019.0
# 4         4019.0
# 6         4019.0
# 7         4019.0
#
# [5 rows x 22 columns]

# %%
melb_data.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df = melb_data[['Type','Price', 'SellerG']].copy()

# %%
df1 = df.groupby(['Type','SellerG']).mean().reset_index()

# %%
df1[:10]
# Out:
#   Type       SellerG         Price
# 0    h       @Realty  4.990000e+05
# 1    h  Abercromby's  3.497667e+06
# 2    h    Alexkarbon  1.256688e+06
# 3    h        Allens  1.461400e+06
# 4    h       Appleby  7.800000e+05
# 5    h        Aquire  5.060000e+05
# 6    h        Ascend  1.690050e+06
# 7    h           Ash  8.100000e+05
# 8    h        Assisi  3.360000e+06
# 9    h    Australian  1.012000e+06

# %%
df2 = df1.pivot(columns='Type',values='Price')

# %%
df3 = df2.merge(df1, left_index=True, right_index=True)

# %%
df4 = df3[['SellerG','h','u','t']]

# %%
df4.h = df4.h.map('${:,.2f}'.format)
df4.u = df4.u.map('${:,.2f}'.format)
df4.t = df4.t.map('${:,.2f}'.format)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11732\3262825054.py in <module>
# ----> 1 df4.h = df4.h.map('${:,.2f}'.format)
#       2 df4.u = df4.u.map('${:,.2f}'.format)
#       3 df4.t = df4.t.map('${:,.2f}'.format)
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    4537         dtype: object
#    4538         """
# -> 4539         new_values = self._map_values(arg, na_action=na_action)
#    4540         return self._constructor(new_values, index=self.index).__finalize__(
#    4541             self, method="map"
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     888
#     889         # mapper is a function
# --> 890         new_values = map_f(values, mapper)
#     891
#     892         return new_values
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ValueError: Unknown format code 'f' for object of type 'str'

# %%
df5 = df4.set_index('SellerG')
df5
# Out:
#                                      h            u     t
# SellerG
# @Realty                    $499,000.00         $nan  $nan
# Abercromby's             $3,497,666.67         $nan  $nan
# Alexkarbon               $1,256,687.50         $nan  $nan
# Allens                   $1,461,400.00         $nan  $nan
# Appleby                    $780,000.00         $nan  $nan
# ...                                ...          ...   ...
# hockingstuart                     $nan  $592,815.26  $nan
# hockingstuart/Advantage           $nan  $330,000.00  $nan
# hockingstuart/Village             $nan  $345,000.00  $nan
# iSell                             $nan  $445,000.00  $nan
# iTRAK                             $nan  $495,000.00  $nan
#
# [357 rows x 3 columns]

# %%
df4.groupby('SellerG').max()
# Out:
#                                    h            u            t
# SellerG
# @Realty                  $499,000.00         $nan         $nan
# Abercromby's                    $nan         $nan         $nan
# Alexkarbon                      $nan         $nan         $nan
# Allens                 $1,461,400.00         $nan         $nan
# Anderson                        $nan  $451,000.00         $nan
# ...                              ...          ...          ...
# hockingstuart/Village           $nan  $345,000.00         $nan
# iOne                            $nan         $nan  $620,000.00
# iProperty                       $nan         $nan  $820,000.00
# iSell                           $nan         $nan         $nan
# iTRAK                           $nan         $nan         $nan
#
# [203 rows x 3 columns]

# %%
Housing_bins

Avgsellingprices = melb_data.groupby(["SellerG"])

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = melb_data.hvplot.points(
    "Longtitude",
    "Lattitude",
    geo = True,
    size = "Rooms",
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color = "SellerG")

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longtitude,Lattitude]   (SellerG,Rooms)

# %%
#read the Melbourne City Real Estate data set
melb_data = pd.read_csv("Properties of Melbourne City (CLEANED)")
#print check
melb_data.head()

#need to drop NA values
melb_data.dropna(inplace=True)
#or use this 
# Drop rows with missing or null values in specific columns
#df.dropna(subset=['column1', 'column2', 'column3', 'column4', 'column5', 'column6', 'column7', 'column8', 'column9', 'column10', 'column11', 'column12', 'column13', 'column14', 'column15', 'column16', 'column17', 'column18', 'column19', 'column20', 'column21', 'column22'], inplace=True)

# %%
#reset the index if needed
melb_data.reset_index(drop=True, inplace=True)

#Skip first row as it is a header
#melb_data_header = next(melb_data)
